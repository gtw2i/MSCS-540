# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

plt.style.use('dark_background')

# %%
data_folder = 'C:/Users/Graham West/Python Notebooks/Meharry Teaching/Datasets/'

df = pd.read_csv(data_folder + 'Real Estate/Real Estate Data.csv', index_col=0, header=0)

df = df.rename(columns = {'OvQual':'Overall Qual',
                          'Built':'Year',
                          'Garage Yr Built':'Year Garage'})

df = df.select_dtypes(include=np.number)
df = df.dropna(axis=0)
df = df.sample(50)

df = df.reset_index(drop=True)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Lot Frontage              50 non-null     float64
#  1   Lot Area                  50 non-null     int64
#  2   Overall Qual              50 non-null     int64
#  3   Overall Cond              50 non-null     int64
#  4   Year                      50 non-null     int64
#  5   Year Remod Add            50 non-null     int64
#  6   Masonry/Veneer Area       50 non-null     float64
#  7   Basement Finished Area    50 non-null     int64
#  8   Basement Unfinished Area  50 non-null     int64
#  9   Basement Area             50 non-null     int64
#  10  1st Floor Area            50 non-null     int64
#  11  2nd Floor Area            50 non-null     int64
#  12  Living Area Above Grade   50 non-null     int64
#  13  Basement Full Baths       50 non-null     int64
#  14  Basement Half baths       50 non-null     int64
#  15  Full Baths Above Grade    50 non-null     int64
#  16  Half Baths Above Grade    50 non-null     int64
#  17  Bedrooms Above Grade      50 non-null     int64
#  18  Kitchens Above Grade      50 non-null     int64
#  19  Total Rooms Above Grade   50 non-null     int64
#  20  Fireplaces                50 non-null     int64
#  21  Year Garage               50 non-null     float64
#  22  Garage Cars               50 non-null     int64
#  23  Garage Area               50 non-null     int64
#  24  Wood Deck Area            50 non-null     int64
#  25  Open Porch Area           50 non-null     int64
#  26  Enclosed Porch Area       50 non-null     int64
#  27  3 Season Porch Area       50 non-null     int64
#  28  Screen Porch Area         50 non-null     int64
#  29  Pool Area                 50 non-null     int64
#  30  Sale Price                50 non-null     int64
# dtypes: float64(3), int64(28)
# memory usage: 12.2 KB
#    Lot Frontage  Lot Area  Overall Qual  Overall Cond  Year  Year Remod Add  \
# 0          82.0      9020             6             5  1964            1964
# 1          77.0      9965             8             5  2006            2007
# 2          40.0      4671             8             5  1988            1989
# 3          70.0     11767             4             7  1910            2000
# 4          60.0      9873             4             5  1970            1970
#
#    Masonry/Veneer Area  Basement Finished Area  Basement Unfinished Area  \
# 0                259.0                     624                       288
# 1                340.0                    1150                       316
# 2                  0.0                     767                       461
# 3                  0.0                       0                       560
# 4                160.0                     789                       171
#
#    Basement Area  1st Floor Area  2nd Floor Area  Living Area Above Grade  \
# 0           1248            1350               0                     1350
# 1           1466            1466            1362                     2828
# 2           1228            1228               0                     1228
# 3            560             796             550                     1346
# 4            960             960               0                      960
#
#    Basement Full Baths  Basement Half baths  Full Baths Above Grade  \
# 0                    1                    0                       1
# 1                    1                    0                       3
# 2                    1                    0                       2
# 3                    0                    0                       1
# 4                    1                    0                       1
#
#    Half Baths Above Grade  Bedrooms Above Grade  Kitchens Above Grade  \
# 0                       1                     3                     1
# 1                       0                     4                     1
# 2                       0                     2                     1
# 3                       1                     2                     1
# 4                       0                     3                     1
#
#    Total Rooms Above Grade  Fireplaces  Year Garage  Garage Cars  Garage Area  \
# 0                        6           0       1964.0            2          520
# 1                       11           1       2006.0            3         1052
# 2                        5           1       1988.0            2          472
# 3                        6           0       1950.0            1          384
# 4                        6           0       1970.0            2          576
#
#    Wood Deck Area  Open Porch Area  Enclosed Porch Area  3 Season Porch Area  \
# 0             176                0                    0                    0
# 1             125              144                    0                    0
# 2             168              120                    0                    0
# 3             168               24                    0                    0
# 4               0              288                    0                    0
#
#    Screen Porch Area  Pool Area  Sale Price
# 0                  0          0      168500
# 1                  0          0      424870
# 2                  0          0      189000
# 3                  0          0      112000
# 4                  0          0      129000
